# %%
import nltk
import random
from nltk.corpus import movie_reviews
from nltk.classify import NaiveBayesClassifier
from nltk.tokenize import word_tokenize
from sklearn.metrics import classification_report

# %%
nltk.download('movie_reviews')

documents = [(list(movie_reviews.words(fileid)), category)
             for category in movie_reviews.categories()
             for fileid in movie_reviews.fileids(category)]

random.shuffle(documents)
# Out:
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Unzipping corpora/movie_reviews.zip.

# %%
def extract_features(words):
  return dict([(word, True) for word in words])


featuresets = [(extract_features(d), c) for (d,c) in documents]

train_set, test_set = featuresets[100:], featuresets[:100]

classifier = NaiveBayesClassifier.train(train_set)

predicted_labels = [classifier.classify(featureset[0]) for featureset in test_set]
true_labels = [label[1] for label in test_set]


print(nltk.classify.accuracy(classifier, test_set))

print(classification_report(true_labels, predicted_labels))
# Out:
# 0.69
#               precision    recall  f1-score   support
#
#          neg       0.93      0.48      0.64        56
#          pos       0.59      0.95      0.73        44
#
#     accuracy                           0.69       100
#    macro avg       0.76      0.72      0.68       100
# weighted avg       0.78      0.69      0.68       100
